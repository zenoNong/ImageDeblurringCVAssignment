# %%
# Install required packages
# !pip install torch torchvision scikit-image
# !pip install --upgrade matplotlib

# Set environment variable to reduce memory fragmentation
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Import libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
import cv2
import matplotlib.pyplot as plt
import gc
import time
from torch.optim.lr_scheduler import CosineAnnealingLR

# Clear GPU memory
torch.cuda.empty_cache()
gc.collect()

# Function to print GPU memory usage
def print_gpu_memory():
    if torch.cuda.is_available():
        print(f"GPU memory allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GiB")
        print(f"GPU memory reserved: {torch.cuda.memory_reserved() / 1024**3:.2f} GiB")

# Function to convert raw events to voxel grid
def events_to_voxel_grid(x, y, timestamps, polarity, num_bins=5, height=128, width=128):
    voxel_grid = np.zeros((num_bins, height, width), dtype=np.float32)
    if timestamps.size > 0:
        t_min, t_max = timestamps.min(), timestamps.max()
        if t_max > t_min:
            t_normalized = (timestamps - t_min) / (t_max - t_min) * (num_bins - 1)
        else:
            t_normalized = np.zeros_like(timestamps)
        
        for i in range(len(x)):
            xi, yi = int(x[i]), int(y[i])
            ti = int(t_normalized[i])
            if 0 <= xi < width and 0 <= yi < height and 0 <= ti < num_bins:
                voxel_grid[ti, yi, xi] += polarity[i]
    return voxel_grid

# Define ConvBlock with Dropout
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dropout_rate=0.1):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout2d(dropout_rate)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.dropout(x)
        return x

# Define Enhanced CrossModalAttention with Multi-Head Attention
class CrossModalAttention(nn.Module):
    def __init__(self, channels, num_heads=4):
        super(CrossModalAttention, self).__init__()
        self.num_heads = num_heads
        self.head_dim = channels // num_heads
        assert self.head_dim * num_heads == channels, "channels must be divisible by num_heads"

        self.query_conv = nn.Conv2d(channels, channels, kernel_size=1)
        self.key_conv = nn.Conv2d(channels, channels, kernel_size=1)
        self.value_conv = nn.Conv2d(channels, channels, kernel_size=1)
        self.softmax = nn.Softmax(dim=-1)
        self.out_conv = nn.Conv2d(channels, channels, kernel_size=1)

    def forward(self, image_features, event_features):
        batch, channels, height, width = image_features.size()
        
        query = self.query_conv(image_features).view(batch, self.num_heads, self.head_dim, height * width)
        key = self.key_conv(event_features).view(batch, self.num_heads, self.head_dim, height * width)
        value = self.value_conv(event_features).view(batch, self.num_heads, self.head_dim, height * width)
        
        query = query.permute(0, 1, 3, 2)  # (batch, heads, H*W, head_dim)
        key = key  # (batch, heads, head_dim, H*W)
        value = value  # (batch, heads, head_dim, H*W)
        
        attention = self.softmax(torch.matmul(query, key) / (self.head_dim ** 0.5))  # (batch, heads, H*W, H*W)
        out = torch.matmul(attention, value.permute(0, 1, 3, 2))  # (batch, heads, H*W, head_dim)
        out = out.permute(0, 1, 3, 2).contiguous().view(batch, channels, height, width)
        
        out = self.out_conv(out)
        return out + image_features

# Define Enhanced EFNet with U-Net-like Structure
class EnhancedEFNet(nn.Module):
    def __init__(self, in_channels=3, event_channels=5, out_channels=3):
        super(EnhancedEFNet, self).__init__()
        # Encoder
        self.image_conv1 = ConvBlock(in_channels, 128)
        self.event_conv1 = ConvBlock(event_channels, 128)
        self.pool = nn.MaxPool2d(2, 2)
        
        self.image_conv2 = ConvBlock(128, 256)
        self.event_conv2 = ConvBlock(128, 256)
        
        # Attention
        self.attention1 = CrossModalAttention(128, num_heads=4)
        self.attention2 = CrossModalAttention(256, num_heads=4)
        
        # Residual Blocks
        self.res_blocks1 = nn.Sequential(
            ConvBlock(128, 128),
            ConvBlock(128, 128),
            ConvBlock(128, 128),
        )
        self.res_blocks2 = nn.Sequential(
            ConvBlock(256, 256),
            ConvBlock(256, 256),
            ConvBlock(256, 256),
        )
        
        # Decoder
        self.upconv = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.final_conv = nn.Conv2d(128, out_channels, kernel_size=3, padding=1)

    def forward(self, blurry_image, event_data):
        # Encoder
        img1 = self.image_conv1(blurry_image)
        evt1 = self.event_conv1(event_data)
        fused1 = self.attention1(img1, evt1)
        fused1 = self.res_blocks1(fused1)
        
        img2 = self.pool(fused1)
        evt2 = self.pool(evt1)
        img2 = self.image_conv2(img2)
        evt2 = self.event_conv2(evt2)
        fused2 = self.attention2(img2, evt2)
        fused2 = self.res_blocks2(fused2)
        
        # Decoder
        up = self.upconv(fused2)
        up = up + fused1  # Skip connection
        deblurred = self.final_conv(up)
        return deblurred

# Custom Dataset for HighREV (Training/Validation)
class HighREVDataset(Dataset):
    def __init__(self, data_dir, phase='train', target_size=(128, 128), num_bins=5):
        self.data_dir = os.path.join(data_dir, phase)
        self.blur_dir = os.path.join(self.data_dir, 'blur')
        self.sharp_dir = os.path.join(self.data_dir, 'sharp')
        self.event_dir = os.path.join(self.data_dir, 'event')
        self.target_size = target_size
        self.num_bins = num_bins
        
        self.blur_files = sorted(os.listdir(self.blur_dir))
        self.event_files = sorted(os.listdir(self.event_dir))
        
        self.file_map = {}
        for blur_file in self.blur_files:
            blur_base = os.path.splitext(blur_file)[0]
            for event_file in self.event_files:
                if blur_base in event_file:
                    self.file_map[blur_file] = event_file
                    break

    def __len__(self):
        return len(self.blur_files)

    def __getitem__(self, idx):
        blur_file = self.blur_files[idx]
        blur_path = os.path.join(self.blur_dir, blur_file)
        blur_img = cv2.imread(blur_path)
        if blur_img is None:
            raise FileNotFoundError(f"Could not load blur image: {blur_path}")
        original_height, original_width = blur_img.shape[:2]
        blur_img = cv2.cvtColor(blur_img, cv2.COLOR_BGR2RGB)
        blur_img = cv2.resize(blur_img, (self.target_size[1], self.target_size[0]))
        blur_img = blur_img.transpose(2, 0, 1) / 255.0
        blur_img = torch.FloatTensor(blur_img)

        sharp_path = os.path.join(self.sharp_dir, blur_file)
        sharp_img = cv2.imread(sharp_path)
        if sharp_img is None:
            raise FileNotFoundError(f"Could not load sharp image: {sharp_path}")
        sharp_img = cv2.cvtColor(sharp_img, cv2.COLOR_BGR2RGB)
        sharp_img = cv2.resize(sharp_img, (self.target_size[1], self.target_size[0]))
        sharp_img = sharp_img.transpose(2, 0, 1) / 255.0
        sharp_img = torch.FloatTensor(sharp_img)

        event_file = self.file_map[blur_file]
        event_path = os.path.join(self.event_dir, event_file)
        npz_data = np.load(event_path)
        x = npz_data['x']
        y = npz_data['y']
        timestamps = npz_data['timestamp']
        polarity = npz_data['polarity']
        
        original_height, original_width = cv2.imread(blur_path).shape[:2]
        x = (x / original_width) * self.target_size[1]
        y = (y / original_height) * self.target_size[0]
        
        event_data = events_to_voxel_grid(
            x, y, timestamps, polarity, self.num_bins, self.target_size[0], self.target_size[1]
        )
        if idx == 0:
            print(f"Event data shape: {event_data.shape}")
            print(f"Blurry image shape: {blur_img.shape}")
        event_data = torch.FloatTensor(event_data)

        return blur_img, event_data, sharp_img, blur_file, (int(original_width), int(original_height))

# Custom Dataset for Test (No Sharp Images)
class HighREVTestDataset(Dataset):
    def __init__(self, data_dir, target_size=(128, 128), num_bins=5):
        self.data_dir = data_dir
        self.blur_dir = os.path.join(self.data_dir, 'blur')
        self.event_dir = os.path.join(self.data_dir, 'event')
        self.target_size = target_size
        self.num_bins = num_bins
        
        self.blur_files = sorted(os.listdir(self.blur_dir))
        self.event_files = sorted(os.listdir(self.event_dir))
        
        self.file_map = {}
        for blur_file in self.blur_files:
            blur_base = os.path.splitext(blur_file)[0]
            for event_file in self.event_files:
                if blur_base in event_file:
                    self.file_map[blur_file] = event_file
                    break

    def __len__(self):
        return len(self.blur_files)

    def __getitem__(self, idx):
        blur_file = self.blur_files[idx]
        blur_path = os.path.join(self.blur_dir, blur_file)
        blur_img = cv2.imread(blur_path)
        if blur_img is None:
            raise FileNotFoundError(f"Could not load blur image: {blur_path}")
        original_height, original_width = blur_img.shape[:2]
        blur_img = cv2.cvtColor(blur_img, cv2.COLOR_BGR2RGB)
        blur_img = cv2.resize(blur_img, (self.target_size[1], self.target_size[0]))
        blur_img = blur_img.transpose(2, 0, 1) / 255.0
        blur_img = torch.FloatTensor(blur_img)

        event_file = self.file_map[blur_file]
        event_path = os.path.join(self.event_dir, event_file)
        npz_data = np.load(event_path)
        x = npz_data['x']
        y = npz_data['y']
        timestamps = npz_data['timestamp']
        polarity = npz_data['polarity']
        
        original_height, original_width = cv2.imread(blur_path).shape[:2]
        x = (x / original_width) * self.target_size[1]
        y = (y / original_height) * self.target_size[0]
        
        event_data = events_to_voxel_grid(
            x, y, timestamps, polarity, self.num_bins, self.target_size[0], self.target_size[1]
        )
        if idx == 0:
            print(f"Test event data shape: {event_data.shape}")
            print(f"Test blurry image shape: {blur_img.shape}")
        event_data = torch.FloatTensor(event_data)

        # Debug the original_size being returned
        original_size = (int(original_width), int(original_height))
        print(f"Dataset item {idx}, blur_file: {blur_file}, original_size: {original_size}")
        return blur_img, event_data, blur_file, original_size

# Custom collate function to preserve original_size as a list of tuples
def custom_collate_fn(batch):
    blurry, events, blur_filename, original_size = zip(*batch)
    return (
        torch.stack(blurry),
        torch.stack(events),
        list(blur_filename),
        list(original_size)  # Preserve original_size as a list of tuples
    )

# Early stopping class
class EarlyStopping:
    def __init__(self, patience=3, min_delta=0, verbose=True):
        self.patience = patience
        self.min_delta = min_delta
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        
    def __call__(self, val_loss, model, epoch, path):
        score = -val_loss
        
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, path)
        elif score < self.best_score + self.min_delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model, epoch, path)
            self.counter = 0
            
    def save_checkpoint(self, val_loss, model, epoch, path):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model ...')
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
        }
        torch.save(checkpoint, path)
        self.val_loss_min = val_loss

# Function to evaluate validation loss
def evaluate_validation_loss(model, val_loader, criterion, device):
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for blurry, events, sharp, _, _ in val_loader:
            blurry, events, sharp = blurry.to(device), events.to(device), sharp.to(device)
            with torch.amp.autocast('cuda'):
                outputs = model(blurry, events)
                loss = criterion(outputs, sharp)
            val_loss += loss.item()
    return val_loss / len(val_loader)

# Enable mixed precision training
from torch.cuda.amp import GradScaler, autocast

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = EnhancedEFNet().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-5)
scaler = GradScaler()
scheduler = CosineAnnealingLR(optimizer, T_max=12)

# Early stopping setup
early_stopping = EarlyStopping(patience=3, verbose=True)
checkpoint_path = '/kaggle/working/best_model.pth'

# Load datasets with num_workers for faster loading
train_dataset = HighREVDataset('/kaggle/input/highrev/HighREV', phase='train', target_size=(128, 128))
val_dataset = HighREVDataset('/kaggle/input/highrev/HighREV', phase='val', target_size=(128, 128))
test_dataset = HighREVTestDataset('/kaggle/input/highrev-testset/HighREV_test/HighREV_test', target_size=(128, 128))
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=2, pin_memory=True, collate_fn=custom_collate_fn)

# Training loop for 6 epochs with gradient accumulation and early stopping
num_epochs = 6
accumulation_steps = 2
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    optimizer.zero_grad()
    for i, (blurry, events, sharp, _, _) in enumerate(train_loader):
        blurry, events, sharp = blurry.to(device), events.to(device), sharp.to(device)

        with torch.amp.autocast('cuda'):
            outputs = model(blurry, events)
            loss = criterion(outputs, sharp) / accumulation_steps
        
        scaler.scale(loss).backward()
        if (i + 1) % accumulation_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad(set_to_none=True)
            torch.cuda.empty_cache()
            gc.collect()
        
        running_loss += loss.item() * accumulation_steps
        if i % 100 == 99:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {running_loss/100:.4f}')
            running_loss = 0.0
        torch.cuda.empty_cache()
        gc.collect()
    
    scheduler.step()
    print(f"Epoch {epoch+1}, Learning Rate: {scheduler.get_last_lr()[0]:.6f}")
    print_gpu_memory()
    
    # Evaluate validation loss and check for early stopping
    val_loss = evaluate_validation_loss(model, val_loader, criterion, device)
    print(f"Validation Loss: {val_loss:.6f}")
    early_stopping(val_loss, model, epoch, checkpoint_path)
    
    if early_stopping.early_stop:
        print("Early stopping triggered!")
        break

# Load the best model for evaluation
best_checkpoint = torch.load(checkpoint_path)
model.load_state_dict(best_checkpoint['model_state_dict'])
print(f"Loaded best model from epoch {best_checkpoint['epoch']+1}")

# Save final checkpoint
final_checkpoint = {
    'epoch': epoch if not early_stopping.early_stop else best_checkpoint['epoch'],
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'scheduler_state_dict': scheduler.state_dict(),
    'scaler_state_dict': scaler.state_dict(),
}
final_checkpoint_path = '/kaggle/working/checkpoint_final.pth'
torch.save(final_checkpoint, final_checkpoint_path)
print(f"Final checkpoint saved at: {final_checkpoint_path}")

# Evaluation on validation set for metrics
model.eval()
psnr_scores = []
ssim_scores = []
val_time = 0.0
print(f"Evaluating {len(val_loader)} validation images for metrics...")

with torch.no_grad():
    for i, (blurry, events, sharp, blur_filename, _) in enumerate(val_loader):
        start_time = time.time()
        blurry, events, sharp = blurry.to(device), events.to(device), sharp.to(device)
        with torch.amp.autocast('cuda'):
            deblurred = model(blurry, events)

        deblurred_np = deblurred.cpu().numpy()
        sharp_np = sharp.cpu().numpy()
        blurry_np = blurry.cpu().numpy()

        for j in range(deblurred_np.shape[0]):
            deblurred_img = deblurred_np[j].transpose(1, 2, 0).astype(np.float32)
            sharp_img = sharp_np[j].transpose(1, 2, 0).astype(np.float32)

            deblurred_img = np.clip(deblurred_img, 0, 1)
            sharp_img = np.clip(sharp_img, 0, 1)

            if deblurred_img.shape[0] < 7 or deblurred_img.shape[1] < 7:
                print(f"Warning: Validation image {blur_filename[j]} too small for SSIM")
                psnr_score = psnr(sharp_img, deblurred_img, data_range=1.0)
                ssim_score = 0
            else:
                psnr_score = psnr(sharp_img, deblurred_img, data_range=1.0)
                ssim_score = ssim(sharp_img, deblurred_img, data_range=1.0, multichannel=True, channel_axis=2)
            psnr_scores.append(psnr_score)
            ssim_scores.append(ssim_score)

        end_time = time.time()
        val_time += end_time - start_time

        del deblurred, blurry, events, sharp, deblurred_np, sharp_np, blurry_np
        torch.cuda.empty_cache()
        gc.collect()

# Process test set and save outputs
total_time = 0.0
output_dir = '/kaggle/working/test_output_final'
os.makedirs(output_dir, exist_ok=True)
print(f"Processing {len(test_loader)} test images...")

with torch.no_grad():
    for i, (blurry, events, blur_filename, original_size) in enumerate(test_loader):
        start_time = time.time()
        blurry, events = blurry.to(device), events.to(device)
        with torch.amp.autocast('cuda'):
            deblurred = model(blurry, events)

        deblurred_np = deblurred.cpu().numpy()
        blurry_np = blurry.cpu().numpy()

        for j in range(deblurred_np.shape[0]):
            deblurred_img = deblurred_np[j].transpose(1, 2, 0).astype(np.float32)
            print(f"Processing test image {blur_filename[j]}")
            print(f"deblurred_img shape: {deblurred_img.shape}, dtype: {deblurred_img.dtype}, min: {deblurred_img.min()}, max: {deblurred_img.max()}")

            if deblurred_img.size == 0 or deblurred_img.shape[0] == 0 or deblurred_img.shape[1] == 0:
                print(f"Warning: Invalid deblurred_img for {blur_filename[j]}, skipping")
                continue

            deblurred_img = np.clip(deblurred_img, 0, 1)

            # Debug and validate original_size
            print(f"Batch {i}, j={j}, original_size[{j}]: {original_size[j]}")
            if not isinstance(original_size[j], (tuple, list)) or len(original_size[j]) != 2:
                raise ValueError(f"Invalid original_size for {blur_filename[j]}: {original_size[j]}. Expected a 2-element tuple (width, height).")

            original_width = int(original_size[j][0])
            original_height = int(original_size[j][1])

            deblurred_resized = cv2.resize(deblurred_img, (original_width, original_height), interpolation=cv2.INTER_LINEAR)
            print(f"deblurred_resized shape: {deblurred_resized.shape}")
            
            blurred = cv2.GaussianBlur(deblurred_resized, (5, 5), 0)
            deblurred_resized = cv2.addWeighted(deblurred_resized, 1.5, blurred, -0.5, 0)
            
            deblurred_img = (deblurred_resized * 255).astype(np.uint8)
            print(f"deblurred_img shape before save: {deblurred_img.shape}")
            deblurred_img = cv2.cvtColor(deblurred_img, cv2.COLOR_RGB2BGR)
            output_path = os.path.join(output_dir, blur_filename[j])
            print(f"Saving deblurred test image to: {output_path}")
            success = cv2.imwrite(output_path, deblurred_img, [cv2.IMWRITE_PNG_COMPRESSION, 0])
            if not success:
                print(f"Failed to save {output_path}")
            else:
                print(f"Successfully saved {output_path}")

        end_time = time.time()
        processing_time = end_time - start_time
        total_time += processing_time
        print(f"Processing time for test batch {i+1}: {processing_time:.2f} seconds")

        if i == 0:
            try:
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.title("Blurry Test Image")
                plt.imshow(blurry_np[0].transpose(1, 2, 0))
                plt.axis('off')
                plt.subplot(1, 2, 2)
                plt.title("Deblurred Test Image")
                plt.imshow(deblurred_resized)
                plt.axis('off')
                plt.show()
            except Exception as e:
                print(f"Error during visualization: {e}")

        del deblurred, blurry, events, deblurred_np, blurry_np, deblurred_resized, deblurred_img
        torch.cuda.empty_cache()
        gc.collect()
        print_gpu_memory()

# Summary
avg_psnr = np.mean(psnr_scores) if psnr_scores else 0.0
avg_ssim = np.mean(ssim_scores) if ssim_scores else 0.0
avg_time_per_image = total_time / (len(test_loader.dataset)) if len(test_loader.dataset) > 0 else 0.0
avg_val_time_per_image = val_time / len(val_loader.dataset) if len(val_loader.dataset) > 0 else 0.0
print(f"Average PSNR (Validation): {avg_psnr:.2f}")
print(f"Average SSIM (Validation): {avg_ssim:.4f}")
print(f"Average runtime per test image: {avg_time_per_image:.2f} seconds")

device_type = 0 if torch.cuda.is_available() and device.type == 'cuda' else 1
extra_data = 0

# Create readme.txt
readme_content = f"""runtime per image [s] : {avg_time_per_image:.2f}
CPU[1] / GPU[0] : {device_type}
Extra Data [1] / No Extra Data [0] : {extra_data}
Average PSNR (Validation) : {avg_psnr:.2f}
Average SSIM (Validation) : {avg_ssim:.4f}
Other description : Enhanced EFNet model with U-Net-like architecture and multi-head CrossModalAttention for event-based deblurring. Trained with early stopping (patience=3) to prevent overfitting and save training time. CosineAnnealingLR scheduling, lower learning rate (0.0005), and weight decay (1e-5). Batch size 1 with accumulation_steps=2 to simulate batch_size=2. Reduced num_bins to 5 for event data. Post-processing includes unsharp masking. Best model saved at {checkpoint_path} and final checkpoint at {final_checkpoint_path}. Deblurred test images saved in {output_dir} as full-quality RGB PNGs at original resolution (1632x1224) with no compression.
"""
readme_path = os.path.join(output_dir, 'readme.txt')
with open(readme_path, 'w') as f:
    f.write(readme_content)

print(f"readme.txt created at: {readme_path}")
print(f"readme.txt content:\n{readme_content}")
print(f"Deblurred test images saved in: {output_dir}")
print("Check the Kaggle output section under '/kaggle/working/test_output_final' for images and readme.txt")
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23->matplotlib) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23->matplotlib) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23->matplotlib) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.23->matplotlib) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.23->matplotlib) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.23->matplotlib) (2024.2.0)
# Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 68.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.5
#     Uninstalling matplotlib-3.7.5:
#       Successfully uninstalled matplotlib-3.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed matplotlib-3.10.1
# <ipython-input-1-44e5ad131ecc>:345: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [1/6], Step [100/1771], Loss: 0.0798
# Epoch [1/6], Step [200/1771], Loss: 0.0360
# Epoch [1/6], Step [300/1771], Loss: 0.0258
# Epoch [1/6], Step [400/1771], Loss: 0.0221
# Epoch [1/6], Step [500/1771], Loss: 0.0219
# Epoch [1/6], Step [600/1771], Loss: 0.0179
# Epoch [1/6], Step [700/1771], Loss: 0.0179
# Epoch [1/6], Step [800/1771], Loss: 0.0163
# Epoch [1/6], Step [900/1771], Loss: 0.0149
# Epoch [1/6], Step [1000/1771], Loss: 0.0153
# Epoch [1/6], Step [1100/1771], Loss: 0.0151
# Epoch [1/6], Step [1200/1771], Loss: 0.0142
# Epoch [1/6], Step [1300/1771], Loss: 0.0161
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [1/6], Step [1400/1771], Loss: 0.0153
# Epoch [1/6], Step [1500/1771], Loss: 0.0123
# Epoch [1/6], Step [1600/1771], Loss: 0.0111
# Epoch [1/6], Step [1700/1771], Loss: 0.0132
# Epoch 1, Learning Rate: 0.000491
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.011356
# Validation loss decreased (inf --> 0.011356). Saving model ...
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [2/6], Step [100/1771], Loss: 0.0104
# Epoch [2/6], Step [200/1771], Loss: 0.0096
# Epoch [2/6], Step [300/1771], Loss: 0.0095
# Epoch [2/6], Step [400/1771], Loss: 0.0096
# Epoch [2/6], Step [500/1771], Loss: 0.0100
# Epoch [2/6], Step [600/1771], Loss: 0.0103
# Epoch [2/6], Step [700/1771], Loss: 0.0094
# Epoch [2/6], Step [800/1771], Loss: 0.0112
# Epoch [2/6], Step [900/1771], Loss: 0.0105
# Epoch [2/6], Step [1000/1771], Loss: 0.0096
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [2/6], Step [1100/1771], Loss: 0.0085
# Epoch [2/6], Step [1200/1771], Loss: 0.0082
# Epoch [2/6], Step [1300/1771], Loss: 0.0087
# Epoch [2/6], Step [1400/1771], Loss: 0.0086
# Epoch [2/6], Step [1500/1771], Loss: 0.0099
# Epoch [2/6], Step [1600/1771], Loss: 0.0086
# Epoch [2/6], Step [1700/1771], Loss: 0.0089
# Epoch 2, Learning Rate: 0.000467
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.011850
# EarlyStopping counter: 1 out of 3
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [3/6], Step [100/1771], Loss: 0.0077
# Epoch [3/6], Step [200/1771], Loss: 0.0076
# Epoch [3/6], Step [300/1771], Loss: 0.0072
# Epoch [3/6], Step [400/1771], Loss: 0.0072
# Epoch [3/6], Step [500/1771], Loss: 0.0079
# Epoch [3/6], Step [600/1771], Loss: 0.0085
# Epoch [3/6], Step [700/1771], Loss: 0.0065
# Epoch [3/6], Step [800/1771], Loss: 0.0061
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [3/6], Step [900/1771], Loss: 0.0051
# Epoch [3/6], Step [1000/1771], Loss: 0.0067
# Epoch [3/6], Step [1100/1771], Loss: 0.0067
# Epoch [3/6], Step [1200/1771], Loss: 0.0062
# Epoch [3/6], Step [1300/1771], Loss: 0.0061
# Epoch [3/6], Step [1400/1771], Loss: 0.0067
# Epoch [3/6], Step [1500/1771], Loss: 0.0065
# Epoch [3/6], Step [1600/1771], Loss: 0.0056
# Epoch [3/6], Step [1700/1771], Loss: 0.0076
# Epoch 3, Learning Rate: 0.000427
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.006846
# Validation loss decreased (0.011356 --> 0.006846). Saving model ...
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [4/6], Step [100/1771], Loss: 0.0062
# Epoch [4/6], Step [200/1771], Loss: 0.0053
# Epoch [4/6], Step [300/1771], Loss: 0.0057
# Epoch [4/6], Step [400/1771], Loss: 0.0060
# Epoch [4/6], Step [500/1771], Loss: 0.0068
# Epoch [4/6], Step [600/1771], Loss: 0.0049
# Epoch [4/6], Step [700/1771], Loss: 0.0054
# Epoch [4/6], Step [800/1771], Loss: 0.0061
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [4/6], Step [900/1771], Loss: 0.0048
# Epoch [4/6], Step [1000/1771], Loss: 0.0044
# Epoch [4/6], Step [1100/1771], Loss: 0.0042
# Epoch [4/6], Step [1200/1771], Loss: 0.0052
# Epoch [4/6], Step [1300/1771], Loss: 0.0059
# Epoch [4/6], Step [1400/1771], Loss: 0.0072
# Epoch [4/6], Step [1500/1771], Loss: 0.0049
# Epoch [4/6], Step [1600/1771], Loss: 0.0071
# Epoch [4/6], Step [1700/1771], Loss: 0.0061
# Epoch 4, Learning Rate: 0.000375
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.008816
# EarlyStopping counter: 1 out of 3
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [5/6], Step [100/1771], Loss: 0.0061
# Epoch [5/6], Step [200/1771], Loss: 0.0071
# Epoch [5/6], Step [300/1771], Loss: 0.0058
# Epoch [5/6], Step [400/1771], Loss: 0.0053
# Epoch [5/6], Step [500/1771], Loss: 0.0044
# Epoch [5/6], Step [600/1771], Loss: 0.0045
# Epoch [5/6], Step [700/1771], Loss: 0.0042
# Epoch [5/6], Step [800/1771], Loss: 0.0054
# Epoch [5/6], Step [900/1771], Loss: 0.0047
# Epoch [5/6], Step [1000/1771], Loss: 0.0041
# Epoch [5/6], Step [1100/1771], Loss: 0.0039
# Epoch [5/6], Step [1200/1771], Loss: 0.0040
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [5/6], Step [1300/1771], Loss: 0.0043
# Epoch [5/6], Step [1400/1771], Loss: 0.0050
# Epoch [5/6], Step [1500/1771], Loss: 0.0043
# Epoch [5/6], Step [1600/1771], Loss: 0.0047
# Epoch [5/6], Step [1700/1771], Loss: 0.0044
# Epoch 5, Learning Rate: 0.000315
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.008935
# EarlyStopping counter: 2 out of 3
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Epoch [6/6], Step [100/1771], Loss: 0.0042
# Epoch [6/6], Step [200/1771], Loss: 0.0042
# Epoch [6/6], Step [300/1771], Loss: 0.0043
# Epoch [6/6], Step [400/1771], Loss: 0.0038
# Epoch [6/6], Step [500/1771], Loss: 0.0042
# Epoch [6/6], Step [600/1771], Loss: 0.0042
# Epoch [6/6], Step [700/1771], Loss: 0.0045
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Epoch [6/6], Step [800/1771], Loss: 0.0040
# Epoch [6/6], Step [900/1771], Loss: 0.0036
# Epoch [6/6], Step [1000/1771], Loss: 0.0036
# Epoch [6/6], Step [1100/1771], Loss: 0.0037
# Epoch [6/6], Step [1200/1771], Loss: 0.0040
# Epoch [6/6], Step [1300/1771], Loss: 0.0038
# Epoch [6/6], Step [1400/1771], Loss: 0.0044
# Epoch [6/6], Step [1500/1771], Loss: 0.0040
# Epoch [6/6], Step [1600/1771], Loss: 0.0042
# Epoch [6/6], Step [1700/1771], Loss: 0.0038
# Epoch 6, Learning Rate: 0.000250
# GPU memory allocated: 0.07 GiB
# GPU memory reserved: 0.16 GiB
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Validation Loss: 0.008282
# EarlyStopping counter: 3 out of 3
# Early stopping triggered!
# Loaded best model from epoch 3
# Final checkpoint saved at: /kaggle/working/checkpoint_final.pth
# Evaluating 421 validation images for metrics...
# <ipython-input-1-44e5ad131ecc>:403: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_checkpoint = torch.load(checkpoint_path)
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Event data shape: (5, 128, 128)
# Blurry image shape: torch.Size([3, 128, 128])
# Processing 284 test images...
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# <ipython-input-1-44e5ad131ecc>:44: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   xi, yi = int(x[i]), int(y[i])
# <ipython-input-1-44e5ad131ecc>:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ti = int(t_normalized[i])
# <ipython-input-1-44e5ad131ecc>:47: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   voxel_grid[ti, yi, xi] += polarity[i]
# Dataset item 1, blur_file: logo_ethzurich_00029.png, original_size: (1632, 1224)
# Test event data shape: (5, 128, 128)
# Test blurry image shape: torch.Size([3, 128, 128])
# Dataset item 0, blur_file: logo_ethzurich_00017.png, original_size: (1632, 1224)
# Processing test image logo_ethzurich_00017.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.0843505859375, max: 0.84228515625
# Batch 0, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00017.png
# Dataset item 2, blur_file: logo_ethzurich_00041.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00017.png
# Processing time for test batch 1: 0.38 seconds
# Dataset item 3, blur_file: logo_ethzurich_00053.png, original_size: (1632, 1224)
# Dataset item 4, blur_file: logo_ethzurich_00065.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00029.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.003662109375, max: 0.83154296875
# Batch 1, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00029.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00029.png
# Processing time for test batch 2: 0.30 seconds
# Dataset item 5, blur_file: logo_ethzurich_00077.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00041.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: -0.010589599609375, max: 0.88134765625
# Batch 2, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00041.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00041.png
# Processing time for test batch 3: 0.24 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00053.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.08740234375, max: 0.79150390625
# Batch 3, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00053.png
# Dataset item 6, blur_file: logo_ethzurich_00089.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00053.png
# Processing time for test batch 4: 0.29 seconds
# Dataset item 7, blur_file: logo_ethzurich_00101.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00065.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.05987548828125, max: 0.77978515625
# Batch 4, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00065.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00065.png
# Processing time for test batch 5: 0.23 seconds
# Dataset item 8, blur_file: logo_ethzurich_00113.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00077.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.09991455078125, max: 0.82421875
# Batch 5, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00077.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00077.png
# Processing time for test batch 6: 0.23 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00089.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.04949951171875, max: 0.89404296875
# Batch 6, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00089.png
# Dataset item 9, blur_file: logo_ethzurich_00125.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00089.png
# Processing time for test batch 7: 0.28 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00101.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.043975830078125, max: 0.93408203125
# Batch 7, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00101.png
# Dataset item 10, blur_file: logo_ethzurich_00137.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00101.png
# Processing time for test batch 8: 0.28 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00113.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.043304443359375, max: 0.85791015625
# Batch 8, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00113.png
# Dataset item 11, blur_file: logo_ethzurich_00149.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00113.png
# Processing time for test batch 9: 0.26 seconds
# Dataset item 12, blur_file: logo_ethzurich_00161.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00125.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.042724609375, max: 0.79443359375
# Batch 9, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00125.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00125.png
# Processing time for test batch 10: 0.23 seconds
# Dataset item 13, blur_file: logo_ethzurich_00173.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00137.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.04559326171875, max: 0.77880859375
# Batch 10, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00137.png
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00137.png
# Processing time for test batch 11: 0.23 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00149.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.0557861328125, max: 0.77978515625
# Batch 11, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00149.png
# Dataset item 14, blur_file: logo_ethzurich_00185.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00149.png
# Processing time for test batch 12: 0.27 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00161.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.052886962890625, max: 0.76123046875
# Batch 12, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/logo_ethzurich_00161.png
# Dataset item 15, blur_file: logo_ethzurich_00197.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/logo_ethzurich_00161.png
# Processing time for test batch 13: 0.28 seconds
# Dataset item 16, blur_file: logo_ethzurich_00209.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image logo_ethzurich_00173.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.036376953125, max: 0.76708984375
# Batch 13, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# ...
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00053.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00053.png
# Processing time for test batch 260: 0.28 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00065.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1676025390625, max: 0.56787109375
# Batch 260, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00065.png
# Dataset item 262, blur_file: zigzag_00089.png, original_size: (1632, 1224)
# Successfully saved /kaggle/working/test_output_final/zigzag_00065.png
# Processing time for test batch 261: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 261, blur_file: zigzag_00077.png, original_size: (1632, 1224)
# Processing test image zigzag_00077.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1654052734375, max: 0.56787109375
# Batch 261, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00077.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00077.png
# Processing time for test batch 262: 0.24 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00089.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1737060546875, max: 0.56591796875
# Batch 262, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00089.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00089.png
# Processing time for test batch 263: 0.23 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 264, blur_file: zigzag_00113.png, original_size: (1632, 1224)
# Dataset item 263, blur_file: zigzag_00101.png, original_size: (1632, 1224)
# Processing test image zigzag_00101.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1690673828125, max: 0.576171875
# Batch 263, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00101.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00101.png
# Processing time for test batch 264: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00113.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1505126953125, max: 0.5556640625
# Batch 264, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00113.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00113.png
# Processing time for test batch 265: 0.29 seconds
# Dataset item 266, blur_file: zigzag_00137.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 265, blur_file: zigzag_00125.png, original_size: (1632, 1224)
# Processing test image zigzag_00125.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1810302734375, max: 0.56640625
# Batch 265, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00125.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00125.png
# Processing time for test batch 266: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00137.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1497802734375, max: 0.5078125
# Batch 266, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00137.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00137.png
# Processing time for test batch 267: 0.29 seconds
# Dataset item 268, blur_file: zigzag_00161.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 267, blur_file: zigzag_00149.png, original_size: (1632, 1224)
# Processing test image zigzag_00149.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.168701171875, max: 0.5703125
# Batch 267, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00149.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00149.png
# Processing time for test batch 268: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00161.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.16015625, max: 0.46484375
# Batch 268, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00161.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00161.png
# Processing time for test batch 269: 0.28 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 270, blur_file: zigzag_00185.png, original_size: (1632, 1224)
# Dataset item 272, blur_file: zigzag_00209.png, original_size: (1632, 1224)
# Dataset item 269, blur_file: zigzag_00173.png, original_size: (1632, 1224)
# Processing test image zigzag_00173.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1434326171875, max: 0.499755859375
# Batch 269, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00173.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00173.png
# Processing time for test batch 270: 0.25 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00185.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1474609375, max: 0.505859375
# Batch 270, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00185.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00185.png
# Processing time for test batch 271: 0.29 seconds
# Dataset item 271, blur_file: zigzag_00197.png, original_size: (1632, 1224)
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00197.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1533203125, max: 0.58203125
# Batch 271, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00197.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00197.png
# Processing time for test batch 272: 0.30 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00209.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.15625, max: 0.5546875
# Batch 272, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00209.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00209.png
# Processing time for test batch 273: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 274, blur_file: zigzag_00233.png, original_size: (1632, 1224)
# Dataset item 273, blur_file: zigzag_00221.png, original_size: (1632, 1224)
# Processing test image zigzag_00221.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1519775390625, max: 0.53564453125
# Batch 273, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00221.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00221.png
# Processing time for test batch 274: 0.30 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00233.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.157958984375, max: 0.484619140625
# Batch 274, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00233.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00233.png
# Processing time for test batch 275: 0.31 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 275, blur_file: zigzag_00245.png, original_size: (1632, 1224)
# Processing test image zigzag_00245.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1756591796875, max: 0.48486328125
# Batch 275, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00245.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00245.png
# Processing time for test batch 276: 0.24 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 277, blur_file: zigzag_00269.png, original_size: (1632, 1224)
# Dataset item 279, blur_file: zigzag_00293.png, original_size: (1632, 1224)
# Dataset item 276, blur_file: zigzag_00257.png, original_size: (1632, 1224)
# Processing test image zigzag_00257.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.17626953125, max: 0.48388671875
# Batch 276, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00257.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00257.png
# Processing time for test batch 277: 0.26 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00269.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.18115234375, max: 0.5458984375
# Batch 277, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00269.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00269.png
# Processing time for test batch 278: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 278, blur_file: zigzag_00281.png, original_size: (1632, 1224)
# Processing test image zigzag_00281.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.172607421875, max: 0.58349609375
# Batch 278, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00281.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00281.png
# Processing time for test batch 279: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00293.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.180419921875, max: 0.7177734375
# Batch 279, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00293.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00293.png
# Processing time for test batch 280: 0.30 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 281, blur_file: zigzag_00317.png, original_size: (1632, 1224)
# Dataset item 280, blur_file: zigzag_00305.png, original_size: (1632, 1224)
# Processing test image zigzag_00305.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1785888671875, max: 0.7099609375
# Batch 280, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00305.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00305.png
# Processing time for test batch 281: 0.29 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00317.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.193359375, max: 0.7470703125
# Batch 281, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00317.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00317.png
# Processing time for test batch 282: 0.30 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Dataset item 283, blur_file: zigzag_00341.png, original_size: (1632, 1224)
# Dataset item 282, blur_file: zigzag_00329.png, original_size: (1632, 1224)
# Processing test image zigzag_00329.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1849365234375, max: 0.6923828125
# Batch 282, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00329.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00329.png
# Processing time for test batch 283: 0.26 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Processing test image zigzag_00341.png
# deblurred_img shape: (128, 128, 3), dtype: float32, min: 0.1844482421875, max: 0.71337890625
# Batch 283, j=0, original_size[0]: [1632, 1224]
# deblurred_resized shape: (1224, 1632, 3)
# deblurred_img shape before save: (1224, 1632, 3)
# Saving deblurred test image to: /kaggle/working/test_output_final/zigzag_00341.png
# Successfully saved /kaggle/working/test_output_final/zigzag_00341.png
# Processing time for test batch 284: 0.23 seconds
# GPU memory allocated: 0.08 GiB
# GPU memory reserved: 0.16 GiB
# Average PSNR (Validation): 22.39
# Average SSIM (Validation): 0.7767
# Average runtime per test image: 0.27 seconds
# readme.txt created at: /kaggle/working/test_output_final/readme.txt
# readme.txt content:
# runtime per image [s] : 0.27
# CPU[1] / GPU[0] : 0
# Extra Data [1] / No Extra Data [0] : 0
# Average PSNR (Validation) : 22.39
# Average SSIM (Validation) : 0.7767
# Other description : Enhanced EFNet model with U-Net-like architecture and multi-head CrossModalAttention for event-based deblurring. Trained with early stopping (patience=3) to prevent overfitting and save training time. CosineAnnealingLR scheduling, lower learning rate (0.0005), and weight decay (1e-5). Batch size 1 with accumulation_steps=2 to simulate batch_size=2. Reduced num_bins to 5 for event data. Post-processing includes unsharp masking. Best model saved at /kaggle/working/best_model.pth and final checkpoint at /kaggle/working/checkpoint_final.pth. Deblurred test images saved in /kaggle/working/test_output_final as full-quality RGB PNGs at original resolution (1632x1224) with no compression.
#
# Deblurred test images saved in: /kaggle/working/test_output_final
# Check the Kaggle output section under '/kaggle/working/test_output_final' for images and readme.txt

# %%
import shutil
shutil.make_archive('/kaggle/working/test_output_final', 'zip', '/kaggle/working/test_output_final')
# Out:
# '/kaggle/working/test_output_final.zip'
